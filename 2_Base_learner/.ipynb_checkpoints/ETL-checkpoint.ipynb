# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
# import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Read data from csv
train = pd.read_csv('../1_Data/Restate_int_train.csv')
test = pd.read_csv('../1_Data/Restate_int_test.csv')
external = pd.read_csv('../1_Data/WRDS.csv') #external data
data_dict = pd.read_excel('../1_Data/DataDictionary_v2.xlsx') #list of features that we are going to use

# %%
data_dict.head()
# Out:
#    Formula                                           Name  \
# 0    gvkey                             Global Company Key
# 1    fyear                             Data Year - Fiscal
# 2  acominc  Accumulated Other Comprehensive Income (Loss)
# 3     aedi           Accrued Expenses and Deferred Income
# 4      act                         Current Assets - Total
#
#                 Account
# 0                   NaN
# 1                   NaN
# 2  Comprehensive Income
# 3      Accrued Expenses
# 4                Assets

# %% [markdown]
# # 1. Exploratory Data Analysis

# %% [markdown]
# ## 1.1 Find percentage of missing data

# %%
data_dict.head()
# Out:
#    Formula                                           Name  \
# 0    gvkey                             Global Company Key
# 1    fyear                             Data Year - Fiscal
# 2  acominc  Accumulated Other Comprehensive Income (Loss)
# 3     aedi           Accrued Expenses and Deferred Income
# 4      act                         Current Assets - Total
#
#                 Account
# 0                   NaN
# 1                   NaN
# 2  Comprehensive Income
# 3      Accrued Expenses
# 4                Assets

# %%
external.head()
# Out:
#    GVKEY  datadate  fyear indfmt consol popsrc datafmt      conm curcd  \
# 0   1004  20050531   2004   INDL      C      D     STD  AAR CORP   USD
# 1   1004  20060531   2005   INDL      C      D     STD  AAR CORP   USD
# 2   1004  20070531   2006   INDL      C      D     STD  AAR CORP   USD
# 3   1004  20080531   2007   INDL      C      D     STD  AAR CORP   USD
# 4   1004  20090531   2008   INDL      C      D     STD  AAR CORP   USD
#
#    acominc     ...      auop  auopic     conml  ggroup      gind  gsector  \
# 0  -19.779     ...       1.0     1.0  AAR Corp  2010.0  201010.0     20.0
# 1  -13.842     ...       1.0     1.0  AAR Corp  2010.0  201010.0     20.0
# 2  -13.899     ...       1.0     1.0  AAR Corp  2010.0  201010.0     20.0
# 3  -13.012     ...       1.0     1.0  AAR Corp  2010.0  201010.0     20.0
# 4  -23.996     ...       1.0     1.0  AAR Corp  2010.0  201010.0     20.0
#
#       gsubind   sic  spcsrc     ipodate
# 0  20101010.0  5080       B  19880101.0
# 1  20101010.0  5080       B  19880101.0
# 2  20101010.0  5080       B  19880101.0
# 3  20101010.0  5080       B  19880101.0
# 4  20101010.0  5080       B  19880101.0
#
# [5 rows x 98 columns]

# %%
#Now we only take the list of features from the DataDictionary_v2.xlsx
feature_list = data_dict['Formula'].values.tolist() #create a list of features
external.rename(columns={'GVKEY': 'gvkey'}, inplace=True)
external = external[feature_list] #filter out
external.rename(columns={'fyear': 'year'}, inplace=True)

#change column name into gvkey and year

# %%
def find_missing(data):
    cnt_missing = data.isnull().sum().values #number of missing values
    total = data.shape[0] # total records
    ratio_missing = cnt_missing/total*100 #percentage of missing
    
    return pd.DataFrame(data ={'missing_count': cnt_missing, 'missing_ratio_percentage' : ratio_missing}, index = data.columns.values)
df_missing = find_missing(external)
df_missing.style.set_properties(**{'text-align': 'left'})
# df_missing.sort_values(['missing_count','missing_ratio_percentage'],ascending = False)
# Out:
# <style  type="text/css" >
#     #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow0_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow0_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow1_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow1_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow2_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow2_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow3_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow3_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow4_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow4_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow5_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow5_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow6_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow6_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow7_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow7_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow8_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow8_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow9_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow9_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow10_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow10_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow11_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow11_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow12_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow12_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow13_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow13_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow14_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow14_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow15_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow15_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow16_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow16_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow17_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow17_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow18_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow18_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow19_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow19_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow20_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow20_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow21_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow21_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow22_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow22_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow23_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow23_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow24_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow24_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow25_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow25_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow26_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow26_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow27_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow27_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow28_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow28_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow29_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow29_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow30_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow30_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow31_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow31_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow32_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow32_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow33_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow33_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow34_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow34_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow35_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow35_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow36_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow36_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow37_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow37_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow38_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow38_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow39_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow39_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow40_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow40_col1 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_953c_7c04d0bdd3berow41_col0 {
#             text-align:  left;
#         }    #T_91b7eee4_543a_11e9_

# %%
#We only take 
df_missing.reset_index(drop= False,inplace = True)
ext_feature = df_missing[df_missing['missing_ratio_percentage']<15]['index'].values #take feature with less than 15% missing values

# %%
#then we are using these feature to merge with our train and test data 
external = external[ext_feature] #filter out these feature
external = external.select_dtypes(exclude=['object']) #for now we dont take categorical features 
train = train.merge(right = external,on =['gvkey','year'],how= 'left')
test = test.merge(right = external,on =['gvkey','year'],how= 'left')

# %%
train.shape
# Out:
# (15213, 45)

# %%
#convert to date time
train['Date'] =  pd.to_datetime(train['Date'])
test['Date'] =  pd.to_datetime(test['Date'])

train.head()
# Out:
#    gvkey  year                Filing       Date  Restate_Int  acominc  \
# 0   1004  2005  0001104659-05-033688 2005-07-22            0  -13.842
# 1   1004  2006  0001104659-06-047248 2006-07-17            0  -13.899
# 2   1004  2007  0001104659-07-055173 2007-07-20            0  -13.012
# 3   1004  2008  0001047469-08-008126 2008-07-11            0  -23.996
# 4   1004  2009  0001047469-09-006783 2009-07-16            0  -29.646
#
#         ap      aqc        at   bkvlps   ...         re     rect      revt  \
# 0   97.002    0.000   978.819  11.5326   ...    183.550  136.272   897.284
# 1  110.239   38.478  1067.633  13.0998   ...    242.153  181.691  1061.169
# 2   99.073   85.210  1362.010  15.0944   ...    318.184  202.472  1384.919
# 3  100.651    0.000  1377.511  16.8937   ...    385.851  227.300  1423.976
# 4  114.906  193.989  1501.042  18.9167   ...    389.641  238.466  1352.151
#
#        seq     tstk  dvpsp_f  dvpsx_f   au  auop  auopic
# 0  422.717   69.664      0.0      0.0  6.0   1.0     1.0
# 1  494.243   79.813      0.0      0.0  6.0   1.0     1.0
# 2  585.255  100.935      0.0      0.0  6.0   1.0     1.0
# 3  656.895  103.159      0.0      0.0  6.0   1.0     1.0
# 4  746.906  104.447      0.0      0.0  6.0   4.0     1.0
#
# [5 rows x 45 columns]

# %%
train['Restate_Int'].value_counts()
# Out:
# 0    14850
# 1      363
# Name: Restate_Int, dtype: int64

# %%
#sort by gvkey and year
train.sort_values(['gvkey','year'],inplace = True)
test.sort_values(['gvkey','year'],inplace = True)

# %%
train['year'].value_counts()
# Out:
# 2005    3112
# 2009    3111
# 2006    3017
# 2008    2998
# 2007    2975
# Name: year, dtype: int64

# %% [markdown]
# # 2.Feature engineering

# %%
train['Weekday'] = train['Date'].dt.dayofweek
test['Weekday'] = test['Date'].dt.dayofweek
test.head()
# Out:
#    gvkey  year                Filing       Date   acominc        ap  aqc  \
# 0   1004  2010  0001047469-10-006500 2010-07-16       NaN       NaN  NaN
# 1   1045  2010  0000006201-10-000006 2010-02-17 -2755.000  1156.000  0.0
# 2   1050  2010  0001193125-10-069639 2010-03-29    -1.608     9.712  0.0
# 3   1072  2010  0000859163-10-000020 2010-05-20       NaN       NaN  NaN
# 4   1075  2010  0000950123-10-014366 2010-02-19  -159.767   236.354  0.0
#
#           at   bkvlps      capx   ...        rect       revt       seq  \
# 0        NaN      NaN       NaN   ...         NaN        NaN       NaN
# 1  25088.000 -11.8309  1962.000   ...     738.000  22170.000 -3945.000
# 2     74.791   2.4565     0.654   ...      26.772    140.602    35.174
# 3        NaN      NaN       NaN   ...         NaN        NaN       NaN
# 4  12362.703  33.8634   765.152   ...     419.518   3263.645  3683.327
#
#       tstk  dvpsp_f  dvpsx_f    au  auop  auopic  Weekday
# 0      NaN      NaN      NaN   NaN   NaN     NaN        4
# 1  367.000      0.0      0.0   4.0   1.0     1.0        2
# 2    0.356      0.0      0.0  11.0   1.0     0.0        0
# 3      NaN      NaN      NaN   NaN   NaN     NaN        3
# 4    2.239      2.1      2.1   5.0   4.0     1.0        4
#
# [5 rows x 45 columns]

# %%
train['Date_lag'] = train.groupby('gvkey')['Date'].shift(1)
test['Date_lag'] = test.groupby('gvkey')['Date'].shift(1)
train['Date_diff'] = (train['Date'] -train['Date_lag']).dt.days -365
test['Date_diff'] = (test['Date'] -test['Date_lag']).dt.days - 365

# %%
train.head()
# Out:
#    gvkey  year                Filing       Date  Restate_Int  acominc  \
# 0   1004  2005  0001104659-05-033688 2005-07-22            0  -13.842
# 1   1004  2006  0001104659-06-047248 2006-07-17            0  -13.899
# 2   1004  2007  0001104659-07-055173 2007-07-20            0  -13.012
# 3   1004  2008  0001047469-08-008126 2008-07-11            0  -23.996
# 4   1004  2009  0001047469-09-006783 2009-07-16            0  -29.646
#
#         ap      aqc        at   bkvlps    ...          seq     tstk  dvpsp_f  \
# 0   97.002    0.000   978.819  11.5326    ...      422.717   69.664      0.0
# 1  110.239   38.478  1067.633  13.0998    ...      494.243   79.813      0.0
# 2   99.073   85.210  1362.010  15.0944    ...      585.255  100.935      0.0
# 3  100.651    0.000  1377.511  16.8937    ...      656.895  103.159      0.0
# 4  114.906  193.989  1501.042  18.9167    ...      746.906  104.447      0.0
#
#    dvpsx_f   au  auop  auopic  Weekday   Date_lag  Date_diff
# 0      0.0  6.0   1.0     1.0        4        NaT        NaN
# 1      0.0  6.0   1.0     1.0        0 2005-07-22       -5.0
# 2      0.0  6.0   1.0     1.0        4 2006-07-17        3.0
# 3      0.0  6.0   1.0     1.0        4 2007-07-20       -8.0
# 4      0.0  6.0   4.0     1.0        3 2008-07-11        5.0
#
# [5 rows x 48 columns]

# %%
train['Week_num'] =train['Date'].dt.week#.dt.date
test['Week_num'] =test['Date'].dt.week#.dt.date
train.head()
# Out:
#    gvkey  year                Filing       Date  Restate_Int  acominc  \
# 0   1004  2005  0001104659-05-033688 2005-07-22            0  -13.842
# 1   1004  2006  0001104659-06-047248 2006-07-17            0  -13.899
# 2   1004  2007  0001104659-07-055173 2007-07-20            0  -13.012
# 3   1004  2008  0001047469-08-008126 2008-07-11            0  -23.996
# 4   1004  2009  0001047469-09-006783 2009-07-16            0  -29.646
#
#         ap      aqc        at   bkvlps    ...        tstk  dvpsp_f  dvpsx_f  \
# 0   97.002    0.000   978.819  11.5326    ...      69.664      0.0      0.0
# 1  110.239   38.478  1067.633  13.0998    ...      79.813      0.0      0.0
# 2   99.073   85.210  1362.010  15.0944    ...     100.935      0.0      0.0
# 3  100.651    0.000  1377.511  16.8937    ...     103.159      0.0      0.0
# 4  114.906  193.989  1501.042  18.9167    ...     104.447      0.0      0.0
#
#     au  auop  auopic  Weekday   Date_lag  Date_diff  Week_num
# 0  6.0   1.0     1.0        4        NaT        NaN        29
# 1  6.0   1.0     1.0        0 2005-07-22       -5.0        29
# 2  6.0   1.0     1.0        4 2006-07-17        3.0        29
# 3  6.0   1.0     1.0        4 2007-07-20       -8.0        28
# 4  6.0   4.0     1.0        3 2008-07-11        5.0        29
#
# [5 rows x 49 columns]

# %%
train.to_csv('../1_Data/Metadata/train.csv')
test.to_csv('../1_Data/Metadata/test.csv')
